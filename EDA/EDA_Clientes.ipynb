# %%
import pandas as pd
import numpy as np

# %%
df_clientes = pd.read_excel(r'C:\Users\pablo\iCloudDrive\Master - ThePower\Data Analyst V3\Repositoros_GitHub\Entrega_Phyton_For_Data\Entrega-Proyecto-Python-EDA\DataProyecto\Bruto\customer-details.xlsx')
df_clientes
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  161770        1         0  2012-04-04                 29
# 1               1   85477        1         1  2012-12-30                  7
# 2               2  147233        1         1  2012-02-02                  5
# 3               3  121393        1         2  2012-12-21                 29
# 4               4   63164        1         2  2012-06-20                 20
# ...           ...     ...      ...       ...         ...                ...
# 20110       20110  114469        0         2  2012-10-28                 13
# 20111       20111   82207        0         1  2012-02-10                 27
# 20112       20112  135009        0         0  2012-09-14                 17
# 20113       20113    8486        1         1  2012-07-04                 18
# 20114       20114  144419        1         0  2012-04-12                 29
#
#                                          ID
# ...

# %%
df_clientes2 = pd.read_excel(r'C:\Users\pablo\iCloudDrive\Master - ThePower\Data Analyst V3\Repositoros_GitHub\Entrega_Phyton_For_Data\Entrega-Proyecto-Python-EDA\DataProyecto\Bruto\customer-details.xlsx',
                             sheet_name = 1)
df_clientes2
# Out:
#       Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0              0   82407        0         1  2013-10-07                 29
# 1              1   24877        0         0  2013-04-21                 32
# 2              2   78839        1         0  2013-11-25                 21
# 3              3  113859        1         1  2013-01-06                 12
# 4              4  147317        0         0  2013-07-10                 14
# ...          ...     ...      ...       ...         ...                ...
# 8960        8960  139839        0         0  2013-12-10                  8
# 8961        8961   65516        0         2  2013-10-01                 26
# 8962        8962   56664        1         0  2013-12-07                 13
# 8963        8963   25089        0         1  2013-08-24                 14
# 8964        8964   77504        0         0  2013-06-30                  6
#
#                                         ID
# ...

# %%
df_clientes3 = pd.read_excel(r'C:\Users\pablo\iCloudDrive\Master - ThePower\Data Analyst V3\Repositoros_GitHub\Entrega_Phyton_For_Data\Entrega-Proyecto-Python-EDA\DataProyecto\Bruto\customer-details.xlsx',
                             sheet_name = 2)
df_clientes3
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  168812        1         1  2014-06-10                 27
# 1               1  108615        2         1  2014-04-05                 24
# 2               2  179041        0         2  2014-09-22                  4
# 3               3  116639        2         2  2014-08-16                  3
# 4               4   49537        0         1  2014-09-05                 28
# ...           ...     ...      ...       ...         ...                ...
# 14085       14085  156980        1         2  2014-05-17                  7
# 14086       14086  139820        0         0  2014-09-29                  1
# 14087       14087   78470        2         2  2014-10-28                 12
# 14088       14088  144218        0         1  2014-07-01                  9
# 14089       14089  115155        0         2  2014-12-25                  7
#
#                                          ID
# ...

# %%
df_clientes = pd.concat([df_clientes,df_clientes2,df_clientes3], axis = 0, ignore_index = True)
df_clientes
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  161770        1         0  2012-04-04                 29
# 1               1   85477        1         1  2012-12-30                  7
# 2               2  147233        1         1  2012-02-02                  5
# 3               3  121393        1         2  2012-12-21                 29
# 4               4   63164        1         2  2012-06-20                 20
# ...           ...     ...      ...       ...         ...                ...
# 43165       14085  156980        1         2  2014-05-17                  7
# 43166       14086  139820        0         0  2014-09-29                  1
# 43167       14087   78470        2         2  2014-10-28                 12
# 43168       14088  144218        0         1  2014-07-01                  9
# 43169       14089  115155        0         2  2014-12-25                  7
#
#                                          ID
# ...

# %%
df_clientes.drop('Unnamed: 0', axis = 1, inplace = True)
df_clientes
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0      161770        1         0  2012-04-04                 29
# 1       85477        1         1  2012-12-30                  7
# 2      147233        1         1  2012-02-02                  5
# 3      121393        1         2  2012-12-21                 29
# 4       63164        1         2  2012-06-20                 20
# ...       ...      ...       ...         ...                ...
# 43165  156980        1         2  2014-05-17                  7
# 43166  139820        0         0  2014-09-29                  1
# 43167   78470        2         2  2014-10-28                 12
# 43168  144218        0         1  2014-07-01                  9
# 43169  115155        0         2  2014-12-25                  7
#
#                                          ID
# 0      089b39d8-e4d0-461b-87d4-814d71e0e079
# 1      e9d37224-cb6f-4942-98d7-46672963d097
# 2      3f9f49b5-e410-4948-bf6e-f9244f04918b
# ...

# %%
df_clientes.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'NumWebVisitsMonth',
#        'ID'],
#       dtype='object')

# %%
df_clientes.dtypes
# Out:
# Income                        int64
# Kidhome                       int64
# Teenhome                      int64
# Dt_Customer          datetime64[ns]
# NumWebVisitsMonth             int64
# ID                           object
# dtype: object

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Income             43170 non-null  int64
#  1   Kidhome            43170 non-null  int64
#  2   Teenhome           43170 non-null  int64
#  3   Dt_Customer        43170 non-null  datetime64[ns]
#  4   NumWebVisitsMonth  43170 non-null  int64
#  5   ID                 43170 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 2.0+ MB

# %%
df_clientes.describe()
# Out:
#               Income       Kidhome      Teenhome  \
# count   43170.000000  43170.000000  43170.000000
# mean    93227.389622      1.004749      0.998633
# min      5841.000000      0.000000      0.000000
# 25%     49608.000000      0.000000      0.000000
# 50%     93009.500000      1.000000      1.000000
# 75%    136740.500000      2.000000      2.000000
# max    180802.000000      2.000000      2.000000
# std     50498.181989      0.815996      0.816008
#
#                          Dt_Customer  NumWebVisitsMonth
# count                          43170       43170.000000
# mean   2013-05-11 22:09:47.407922176          16.591290
# min              2012-01-01 00:00:00           1.000000
# 25%              2012-07-16 00:00:00           9.000000
# 50%              2013-03-01 00:00:00          17.000000
# 75%              2014-03-28 00:00:00          25.000000
# max              2014-12-31 00:00:00          32.000000
# std                              NaN           9.241769

# %% [markdown]
# ## Continuar
